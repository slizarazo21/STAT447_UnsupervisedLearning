# %% [markdown]
# # Assignment 6 - [30 points]
#
# ##  Seattle Airbnb Listing Analysis
#
# Suppose that you work as a data scientist at Airbnb. You'd like to learn more about the main different types of Airbnb listings in the Seattle area and then use this information to advertise these different types of listings to interested customers.
#
# The following dataset is a sample of available Airbnb listings in Seattle, WA. These listings were collected in January 2016, and filtered to just contain listings from some of the most popular Seattle neighborhoods (for Airbnb listings) and just contain listings that are either in a house or apartment property. Rows with missing values have already been dropped from the dataset.
#
# This dataset contains the following variables.
#
# **Listing Information**
# The dataset contains the following information about the Airbnb *listing*:
# * <u>price</u>: price of the listing (per night)(in US dollars)
# * <u>review_scores_rating</u>: the average rating of the listing [0,100] (100 is the best)
# * <u>number_of_reviews</u>: the number of reviews for the listing
# * <u>security_deposit</u>: the security deposit required for the listing (in US dollars)
# * <u>cleaning_fee</u>: the cleaning fee required for the listing (in US dollars)
# * <u>neighborhood</u>: the neighborhood of Seattle the listing is located in
# * <u>property_type</u>: is the listing in a 'House' or 'Apartment'
# * <u>room_type</u>: is the listing a 'Entire home/apt', 'Private room', or 'Shared room'
# * <u>accommodates</u>: how many guests will the listing accommodate
# * <u>bathrooms</u>:how many bathrooms does the listing have
# * <u>beds</u>: how many beds does the listing have
#
# **Host Information**
# The dataset also contains the following information about the *host* of the given Airbnb listing:
# * <u>host_is_superhost</u>: is the host a "superhost": t=True, f=False
# * <u>host_has_profile_pic</u>: does the host have a profile pic in their bio: t=True, f=False
# * <u>host_response_time</u>: how fast will the host respond to requests (on average)
# * <u>host_acceptance_rate</u>: what percent of booking requests will the host accept
#
# ### <u>Case Study 1</u>: Reduced Dataset - *Just Categorical Variables*
#
# In this assignment 6, we would like to try clustering our Airbnb listing dataset for now using just the categorical variables. In assignment 7 we will consider the full dataset which will use the categorical and the numerical variables.
#
# ### <u>Research Goals</u>:
#
# In this analysis, we have the following research goals.
#
# 1. Identify larger "main clusters" of Airbnb listings in the Seattle area. In general, we would like for most of our listings to be clustered in with a larger sized clusters, rather than be separated as small or singleton clusters.
# 2. We would also like to identify potential sub-clusters of listings within each of the "main clusters."
# 3. What attributes characterize each of these clusters and sub-clusters?

# %% [markdown]
# #### Imports

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from scipy.spatial.distance import pdist, squareform
from sklearn.manifold import TSNE

from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.cluster import AgglomerativeClustering
from kmodes.kmodes import KModes
from sklearn import preprocessing

# %% [markdown]
# ## 1. Data Preprocessing and Cleaning
#
# ### 1.1. Original Dataset
# Read the seattle_airbnb_listings_cleaned.csv into a dataframe. This dataframe has already been cleaned (rows with missing values have already been dropped).

# %%
df = pd.read_csv('seattle_airbnb_listings_cleaned.csv')

# %%
df.describe()
# Out:
#             price  review_scores_rating  number_of_reviews  security_deposit  \
# count  232.000000            232.000000         232.000000        232.000000
# mean   128.426724             92.719828          22.275862        258.853448
# std     91.734058              9.776017          25.688304        139.632961
# min     35.000000             20.000000           1.000000         95.000000
# 25%     85.000000             90.000000           4.000000        150.000000
# 50%    110.000000             96.000000          12.000000        250.000000
# 75%    149.250000             99.000000          32.000000        350.000000
# max    999.000000            100.000000         124.000000        800.000000
#
#        cleaning_fee  accommodates   bathrooms    bedrooms        beds  \
# count    232.000000    232.000000  232.000000  232.000000  232.000000
# mean      60.426724      3.538793    1.221983    1.254310    1.810345
# std       36.855207      1.986590    0.545814    0.930474    1.161532
# min        5.000000      1.000000    1.000000    0.000000    1.000000
# 25%       35.000000      2.000000    1.000000    1.000000    1.000000
# 50%       60.000000      3.000000    1.000000    1.000000    1.000000
# 75%       75.000000      4.000000    1.000000    2.000000    2.000000
# max      250.000000     12.000000    3.500000    5.000000    7.000000
#
#        host_response_rate  host_acceptance_rate
# count          232.000000                 232.0
# mean             0.941207                   1.0
# std              0.091454                   0.0
# min              0.500000                   1.0
# 25%              0.900000                   1.0
# 50%              1.000000                   1.0
# 75%              1.000000                   1.0
# max              1.000000                   1.0

# %%
df.head()
# Out:
#    price  review_scores_rating  number_of_reviews  security_deposit  \
# 0    300                   100                 24               500
# 1    149                    96                 11               300
# 2     95                    95                 79               150
# 3    105                   100                 13               500
# 4    140                    99                 30               250
#
#    cleaning_fee neighborhood property_type        room_type  accommodates  \
# 0            95  Wallingford         House  Entire home/apt             5
# 1           105  Wallingford     Apartment  Entire home/apt             6
# 2            40  Wallingford     Apartment  Entire home/apt             3
# 3            50  Wallingford         House     Private room             2
# 4            65  Wallingford         House  Entire home/apt             2
#
#    bathrooms  bedrooms  beds  host_response_time  host_response_rate  \
# 0        1.5         3     3  within a few hours                 1.0
# 1        1.0         2     3      within an hour                 1.0
# 2        1.0         1     2      within an hour                 1.0
# 3        2.0         1     1  within a few hours                 1.0
# 4        1.0         1     1      within an hour                 1.0
#
#    host_acceptance_rate host_is_superhost host_has_profile_pic  \
# 0                     1                 t                    t
# 1                     1                 f                    t
# 2                     1                 f                    t
# 3                     1                 t                    t
# 4                     1                 t                    t
#
#   host_identity_verified
# 0                      t
# 1                      t
# 2                      t
# 3                      t
# 4                      t

# %% [markdown]
# ### 1.2. Categorical Dataset
#
# Next, create a dataframe that is just comprised of the categorical variables.

# %%
df_cat = df[['neighborhood', 'property_type', 'room_type', 'host_response_time', 'host_is_superhost', 'host_has_profile_pic', 'host_identity_verified']]

# %%
df_cat.describe()
# Out:
#        neighborhood property_type        room_type host_response_time  \
# count           232           232              232                232
# unique            4             2                3                  3
# top     Wallingford     Apartment  Entire home/apt     within an hour
# freq             70           127              180                131
#
#        host_is_superhost host_has_profile_pic host_identity_verified
# count                232                  232                    232
# unique                 2                    2                      2
# top                    f                    t                      t
# freq                 161                  231                    196

# %% [markdown]
# ### 1.3. Label Encoding
#
# Next, label encode this dataframe that is comprised of just your numerical variables. *That is, each distinct value in each of your categorical variables should be represented with a number.*

# %%
df_cat2 = df_cat.copy()

labels_a = {}
for col in df_cat.columns:
    labels_a[col] = preprocessing.LabelEncoder()
    print(col)
    df_cat2[col] = labels_a[col].fit_transform(df_cat[col])


df_cat2.head()
labels_a
# Out:
# neighborhood
# property_type
# room_type
# host_response_time
# host_is_superhost
# host_has_profile_pic
# host_identity_verified
# {'neighborhood': LabelEncoder(),
#  'property_type': LabelEncoder(),
#  'room_type': LabelEncoder(),
#  'host_response_time': LabelEncoder(),
#  'host_is_superhost': LabelEncoder(),
#  'host_has_profile_pic': LabelEncoder(),
#  'host_identity_verified': LabelEncoder()}

# %% [markdown]
# ### 1.4 Hamming distance matrix
#
# Finally, create a Hamming distance matrix of your categorical variables.

# %%
dist_m = squareform(pdist(df_cat2, metric = 'hamming'))
dist_m
# Out:
# array([[0.        , 0.42857143, 0.42857143, ..., 0.42857143, 0.71428571,
#         0.28571429],
#        [0.42857143, 0.        , 0.        , ..., 0.28571429, 0.85714286,
#         0.42857143],
#        [0.42857143, 0.        , 0.        , ..., 0.28571429, 0.85714286,
#         0.42857143],
#        ...,
#        [0.42857143, 0.28571429, 0.28571429, ..., 0.        , 0.57142857,
#         0.14285714],
#        [0.71428571, 0.85714286, 0.85714286, ..., 0.57142857, 0.        ,
#         0.42857143],
#        [0.28571429, 0.42857143, 0.42857143, ..., 0.14285714, 0.42857143,
#         0.        ]])

# %% [markdown]
# ## 2. Clusterability
#
# ### 2.1. t-SNE Plots
# Using 6 different perplexity values and at least two random states for each perplexity value, map this **distance matrix** onto a two-dimensional dataset with the t-SNE algorithm. Show your projected coordinates in a scatterplot for each combination of random states and perplexity value.

# %%
for perp in [5,15, 20, 30, 40, 50]:
    for rs in [10, 88]:
        tsne = TSNE(n_components=2, perplexity=perp, random_state=rs, metric='precomputed', init='random')
        data_tsne = tsne.fit_transform(dist_m)
        df_tsne = pd.DataFrame(data_tsne, columns=['x_projected', 'y_projected'])
        df_combo = pd.concat([df_cat, df_tsne], axis=1)
        sns.scatterplot(x='x_projected',y='y_projected', data=df_combo, color = 'red')
        plt.title('t-SNE Plot  Perplexity Value %s / Random State %s' %(perp, rs))
        plt.show()
    print('--------------------------------------------')
# Out:
# --------------------------------------------
# --------------------------------------------
# --------------------------------------------
# --------------------------------------------
# --------------------------------------------
# --------------------------------------------

# %% [markdown]
# ### 2.2 Assessing Clustering Structure
#
# Answer the following questions below.
#
# 1. Does the t-SNE algorith suggest that this dataset is clusterable?
#
# tSNE plots suggest some cluster structure in the dataset. This can be observed as perplexity values increases
#
# 2. How many "main clusters" do you think that this dataset has? *[Subjective Answer: As long as your logic is correct, you will not lose points].*
#
# Starting at a perplexity value of 15 up to 50 it is possible to observe 3 possible main clusters. Important to mention that these clusters do not appear to have same sizes
#
# Finally, pick out a random state and perplexity value that reflects the answers to your questions and show the corresponding t-SNE plot below.
#
# Perplexity = 40. Random State = 88

# %%
tsne = TSNE(n_components=2, perplexity=40, random_state=88, metric='precomputed', init='random')
data_tsne = tsne.fit_transform(dist_m)
df_tsne = pd.DataFrame(data_tsne, columns=['x_projected', 'y_projected'])
df_combo = pd.concat([df_cat, df_tsne], axis=1)
sns.scatterplot(x='x_projected',y='y_projected', data=df_combo, color = 'black')
plt.title('t-SNE Plot  Perplexity Value 40 / Random State 88' )
plt.show()

# %% [markdown]
# ### 2.3. Association between the Attributes and the Clustering Structure Suggested by the t-SNE Plots
#
# Finally, we would like to assess how each of our 7 categorical attributes is individually associated with the clustering structure suggested by our selected t-SNE from 2.2. In the code below, plot your t-SNE plot 7 times, each time color coding the points by each of the 7 categorical attributes.

# %%
for i in df_combo.columns[0:6]:
    sns.scatterplot(x = 'x_projected', y = 'y_projected', hue = i, data = df_combo)
    plt.title(i)
    plt.legend(bbox_to_anchor = (1,1))
    plt.show()

# %% [markdown]
# ### 2.4. Interpretation
#
# Select one of the smaller *highly* dense clouds of points in your t-SNE plot. Do the categorical attribute values in the points in this dense cloud that you selected differ at all?

# %% [markdown]
# It is possible to observe that the highly dense cloud that has a ring-like structure with coordinates (0,6) presents unique attributes across the different categories assessed.

# %% [markdown]
# ## 3. K-Modes - *Parameter Selection*
#
# Next, we would like to cluster this dataset with the k-modes algorithm. We would like to explore what the best values of $k$  would be to use in this clustering algorithm to meet our research goals.

# %% [markdown]
# ### 3.1. Elbow Plot
#
# Create an elbow plot for the k-modes algorithm. Your plot should assess clusterings with k=1, k=2,..., k=16 clusters. For each k, run a single k-modes algorithm, using a random state of 100.

# %%
clust_df = []
for k in list(range(1,17)):
    kmode = KModes(n_clusters = k)
    kmode.fit_predict(df_cat2)
    clust_df.append(kmode.cost_)

clust_df
# Out:
# [528.0,
#  446.0,
#  388.0,
#  367.0,
#  308.0,
#  277.0,
#  211.0,
#  197.0,
#  192.0,
#  187.0,
#  179.0,
#  176.0,
#  144.0,
#  144.0,
#  140.0,
#  138.0]

# %%
plt.plot(range(1,17), clust_df, color = 'black')
plt.xlabel('K Clusters')
plt.ylabel('Cost')
plt.title('Elbow Plot for K-Modes')
plt.show()

# %% [markdown]
# ### 3.2. t-SNE Plots
#
# For k=1, k=2,..., k=10, run the k-modes clustering algorithm on your dataset, using a random state of 100. For each of your clusterings, plot a t-SNE plot in which you have color coded the points by their cluster labels.

# %%
for k in range(1,11):
    km = KModes(n_clusters = k, random_state = 100)
    labels = km.fit_predict(df_cat2)
    df_combo['predicted_clust'] = labels
    sns.scatterplot(x='x_projected',y='y_projected', hue='predicted_clust', palette=sns.color_palette("husl", k), data=df_combo)
    plt.title('t-SNE Plot with k-Modes with k=%s Clusters' %(k))
    plt.legend(bbox_to_anchor=(1,1))
    plt.show()
    print('Next K Comming up!')
# Out:
# Next K Comming up!
# Next K Comming up!
# Next K Comming up!
# Next K Comming up!
# Next K Comming up!
# Next K Comming up!
# Next K Comming up!
# Next K Comming up!
# Next K Comming up!
# Next K Comming up!

# %% [markdown]
# ### 3.3. Interpretation
#
# How many clusters does your elbow plot suggest are in this dataset? Does the k-modes clustering with this k number of clusters *strongly* agree with the clustering structured suggested by the t-SNE plot?

# %% [markdown]
# The elbow plot suggest a total of 7 clusters. By assessing the tSNE plot with 7 clusters there is no strong agreement.

# %% [markdown]
# ### 3.4. Clustering Again
#
# Use the value of k that you selected in your elbow plot to cluster the dataset one more time using k-modes.

# %%
km = KModes(n_clusters = 7, random_state = 100)
labels = km.fit_predict(df_cat2)
df_combo['predicted_clust'] = labels

# %% [markdown]
# ### 3.5. Cluster Modes
#
# Display the modes for each of your clusters in this clustering that you found in 3.4. Your modes should be *unencoded* so you are able to examine the actual attribute values that correspond to each of the modes.

# %%
centroids = pd.DataFrame(km.cluster_centroids_, columns = df_cat2.columns)
centroids_dec = centroids.copy()

for i in centroids.columns:
    centroids_dec[i] = labels_a[i].inverse_transform(centroids[i])
centroids_dec
# Out:
#           neighborhood property_type        room_type  host_response_time  \
# 0          Wallingford     Apartment  Entire home/apt      within an hour
# 1                Minor         House     Private room  within a few hours
# 2  University District         House  Entire home/apt      within an hour
# 3          Wallingford         House  Entire home/apt      within an hour
# 4             Belltown     Apartment  Entire home/apt      within an hour
# 5                Minor         House  Entire home/apt  within a few hours
# 6  University District     Apartment  Entire home/apt  within a few hours
#
#   host_is_superhost host_has_profile_pic host_identity_verified
# 0                 f                    t                      t
# 1                 t                    t                      t
# 2                 f                    t                      f
# 3                 t                    t                      t
# 4                 t                    t                      t
# 5                 f                    t                      t
# 6                 f                    t                      t

# %% [markdown]
# ### 3.6. Describing the Clusters
#
# Next, we would like to describe how each of our 7 categorical attributes *associates* with each of the clusters in our clustering.
#
# #### 3.6.1. Cluster Label Distribution for each Distinct Attribute Level
#
# First, create 7 side-by-side barplot figures.
#
# 1. One that visualizes the relationship between neighborhood and cluster labels.
# 2. One that visualizes the relationship between property_type and cluster labels.
#
# ...
#
# 7. One that visualizes the relationship between host_identity_verified and cluster labels.
#
# For each of these figures, your "attribute" should be in the "x-axis".

# %%
df_cat['predicted_clust'] = df_combo['predicted_clust']
df_combo['predicted_clust'].value_counts()
# Out:
# 0    80
# 6    39
# 4    33
# 2    25
# 5    23
# 1    18
# 3    14
# Name: predicted_clust, dtype: int64

# %%
for i in df_cat.columns[0:7]:
    ctab = pd.crosstab(df_cat[i], df_cat['predicted_clust'], normalize = 'index')
    print(ctab)
    print('plot')
    ctab.plot.bar()
    plt.show()
# Out:
# predicted_clust             0         1         2         3         4  \
# neighborhood
# Belltown             0.385965  0.000000  0.000000  0.000000  0.473684
# Minor                0.142857  0.326531  0.081633  0.061224  0.102041
# University District  0.071429  0.000000  0.339286  0.017857  0.017857
# Wallingford          0.671429  0.028571  0.028571  0.142857  0.000000
#
# predicted_clust             5         6
# neighborhood
# Belltown             0.000000  0.140351
# Minor                0.285714  0.000000
# University District  0.000000  0.553571
# Wallingford          0.128571  0.000000
# plot
# predicted_clust         0         1         2         3         4         5  \
# property_type
# Apartment        0.417323  0.000000  0.007874  0.000000  0.259843  0.007874
# House            0.257143  0.171429  0.228571  0.133333  0.000000  0.209524
#
# predicted_clust         6
# property_type
# Apartment        0.307087
# House            0.000000
# plot
# predicted_clust         0         1         2         3         4         5  \
# room_type
# Entire home/apt  0.338889  0.011111  0.066667  0.066667  0.177778  0.127778
# Private room     0.147059  0.470588  0.323529  0.058824  0.000000  0.000000
# Shared room      0.777778  0.000000  0.111111  0.000000  0.055556  0.000000
#
# predicted_clust         6
# room_type
# Entire home/apt  0.211111
# Private room     0.000000
# Shared room      0.055556
# plot
# predicted_clust            0         1         2         3         4  \
# host_response_time
# within a day        0.500000  0.222222  0.166667  0.000000  0.055556
# within a few hours  0.084337  0.120482  0.036145  0.012048  0.072289
# within an hour      0.488550  0.030534  0.145038  0.099237  0.198473
#
# predicted_clust            5        6
# host_response_time
# within a day        0.055556  0.00000
# within a few hours  0.204819  0.46988
# within an hour      0.038168  0.00000
# plot
# predicted_clust           0         1         2         3         4         5  \
# host_is_superhost
# f                  0.453416  0.012422  0.149068  0.000000  0.000000  0.142857
# t                  0.098592  0.225352  0.014085  0.197183  0.464789  0.000000
#
# predicted_clust           6
# host_is_superhost
# f                  0.242236
# t                  0.000000
# plot
# predicted_clust             0         1         2         3         4  \
# host_has_profile_pic
# f                     0.00000  0.000000  0.000000  0.000000  1.000000
# t                     0.34632  0.077922  0.108225  0.060606  0.138528
#
# predicted_clust              5         6
# host_has_profile_pic
# f                     0.000000  0.000000
# t                     0.099567  0.168831
# plot
# predicted_clust                0         1         2         3         4  \
# host_identity_verified
# f                       0.166667  0.000000  0.555556  0.000000  0.138889
# t                       0.377551  0.091837  0.025510  0.071429  0.142857
#
# predicted_clust                5         6
# host_identity_verified
# f                       0.000000  0.138889
# t                       0.117347  0.173469
# plot

# %% [markdown]
# #### 3.6.2. Plot Interpretation
#
# Which cluster do Wallingford listing houses most belong to?

# %% [markdown]
# Cluster 0

# %% [markdown]
# #### 3.6.3. Cluster Label Distribution for each Distinct Attribute Level
#
# Next, create 7 side-by-side barplot figures.
#
# 1. One that visualizes the relationship between neighborhood and cluster labels.
# 2. One that visualizes the relationship between property_type and cluster labels.
#
# ...
#
# 7. One that visualizes the relationship between host_identity_verified and cluster labels.
#
# For each of these figures, your "cluster labels" should be in the "x-axis".

# %%
for i in df_cat.columns[0:7]:
    ctab = pd.crosstab( df_cat['predicted_clust'],df_cat[i], normalize = 'index')
    print(ctab)
    print('plot')
    ctab.plot.bar()
    plt.show()
# Out:
# neighborhood     Belltown     Minor  University District  Wallingford
# predicted_clust
# 0                0.275000  0.087500             0.050000     0.587500
# 1                0.000000  0.888889             0.000000     0.111111
# 2                0.000000  0.160000             0.760000     0.080000
# 3                0.000000  0.214286             0.071429     0.714286
# 4                0.818182  0.151515             0.030303     0.000000
# 5                0.000000  0.608696             0.000000     0.391304
# 6                0.205128  0.000000             0.794872     0.000000
# plot
# property_type    Apartment     House
# predicted_clust
# 0                 0.662500  0.337500
# 1                 0.000000  1.000000
# 2                 0.040000  0.960000
# 3                 0.000000  1.000000
# 4                 1.000000  0.000000
# 5                 0.043478  0.956522
# 6                 1.000000  0.000000
# plot
# room_type        Entire home/apt  Private room  Shared room
# predicted_clust
# 0                       0.762500      0.062500     0.175000
# 1                       0.111111      0.888889     0.000000
# 2                       0.480000      0.440000     0.080000
# 3                       0.857143      0.142857     0.000000
# 4                       0.969697      0.000000     0.030303
# 5                       1.000000      0.000000     0.000000
# 6                       0.974359      0.000000     0.025641
# plot
# host_response_time  within a day  within a few hours  within an hour
# predicted_clust
# 0                       0.112500            0.087500        0.800000
# 1                       0.222222            0.555556        0.222222
# 2                       0.120000            0.120000        0.760000
# 3                       0.000000            0.071429        0.928571
# 4                       0.030303            0.181818        0.787879
# 5                       0.043478            0.739130        0.217391
# 6                       0.000000            1.000000        0.000000
# plot
# host_is_superhost         f         t
# predicted_clust
# 0                  0.912500  0.087500
# 1                  0.111111  0.888889
# 2                  0.960000  0.040000
# 3                  0.000000  1.000000
# 4                  0.000000  1.000000
# 5                  1.000000  0.000000
# 6                  1.000000  0.000000
# plot
# host_has_profile_pic         f         t
# predicted_clust
# 0                     0.000000  1.000000
# 1                     0.000000  1.000000
# 2                     0.000000  1.000000
# 3                     0.000000  1.000000
# 4                     0.030303  0.969697
# 5                     0.000000  1.000000
# 6                     0.000000  1.000000
# plot
# host_identity_verified         f         t
# predicted_clust
# 0                       0.075000  0.925000
# 1                       0.000000  1.000000
# 2                       0.800000  0.200000
# 3                       0.000000  1.000000
# 4                       0.151515  0.848485
# 5                       0.000000  1.000000
# 6                       0.128205  0.871795
# plot

# %% [markdown]
# #### 3.6.4. Plot Interpretation
#
# Which neighborhood to the the listings in cluster 1 most belong to?

# %% [markdown]
# Minor Neighborhood.  NOTE: I looked for cluster 1, instead of cluster 0

# %% [markdown]
# ## 4. Hierarchical Agglomerative Clustering
#
# Next, we would like to cluster our Hamming distance matrix with hierarchical agglomerative clustering using single linkage, complete linkage, and average linkage.

# %% [markdown]
# ### 4.1. Single Linkage
#
# #### 4.1.1. Dendrogram
#
# Create a dendrogram using hierarchical agglomerative clustering with single linkage for using your Hamming distance matrix.
# * Because this is a small dataset, we do not need/want to truncate our dendrogram results. You should be able to see the indices of each of your observations at the leaves of your dendrogram tree.
# * Make sure you are able to read the indices labels in your dendrogram.

# %%
dist_m = pdist(df_cat2, metric = 'hamming')
link = linkage(dist_m, method = 'single')

# %%
fig, ax = plt.subplots(figsize=(30, 30))
d = dendrogram(link, orientation='right', ax=ax)
ax.set_xlabel('Dissimilarity', fontsize=18)
ax.set_ylabel('Indices', fontsize=18)
plt.yticks(fontsize=10)
plt.title('Single Linkage', fontsize=18)
plt.show()

# %% [markdown]
# #### 4.1.2  t-SNE Individual Clustering Visualization
#
# Then for each of the clusterings with k=2,k=3,...,k=10 clusters, color code the points in your selected t-SNE plot with the respective cluster labels.

# %%
dist_s = squareform(pdist(df_cat2, metric = 'hamming'))
for k in range(2,11):
    #Clustering from dendrogram with k clusters
    hac = AgglomerativeClustering(n_clusters=k, affinity='precomputed', linkage='single')
    df_combo['predicted_cluster'] = hac.fit_predict(dist_s)
    
    #Map the resulting cluster labels onto our chosen t-SNE plot
    sns.scatterplot(x='x_projected',y='y_projected', hue='predicted_cluster', palette=sns.color_palette("husl", k), data=df_combo)
    plt.title('t-SNE Plot with Single Linkage Clustering with k=%s Clusters' %(k))
    plt.legend(bbox_to_anchor=(1,1))
    plt.show()

# %% [markdown]
# ### 4.2. Complete Linkage
#
# #### 4.2.1. Dendrogram
#
# Create a dendrogram using hierarchical agglomerative clustering with complete linkage using your Hamming distance matrix.
# * Because this is a small dataset, we do not need/want to truncate our dendrogram results. You should be able to see the indices of each of your observations at the leaves of your dendrogram tree.
# * Make sure you are able to read the indices labels in your dendrogram.

# %%
dist_m = pdist(df_cat2, metric = 'hamming')
link = linkage(dist_m, method = 'complete')

# %%
fig, ax = plt.subplots(figsize=(30, 30))
d = dendrogram(link, orientation='right', ax=ax)
ax.set_xlabel('Dissimilarity', fontsize=18)
ax.set_ylabel('Indices', fontsize=18)
plt.yticks(fontsize=10)
plt.title('Complete Linkage', fontsize=18)
plt.show()

# %% [markdown]
# #### 4.2.2  t-SNE Individual Clustering Visualization
#
# Then for each of the clusterings with k=2,k=3,...,k=10 clusters, color code the points in your selected t-SNE plot with the respective cluster labels.

# %%
dist_s = squareform(pdist(df_cat2, metric = 'hamming'))
for k in range(2,11):
    #Clustering from dendrogram with k clusters
    hac = AgglomerativeClustering(n_clusters=k, affinity='precomputed', linkage='complete')
    df_combo['predicted_cluster'] = hac.fit_predict(dist_s)
    
    #Map the resulting cluster labels onto our chosen t-SNE plot
    sns.scatterplot(x='x_projected',y='y_projected', hue='predicted_cluster', palette=sns.color_palette("husl", k), data=df_combo)
    plt.title('t-SNE Plot with Complete Linkage Clustering with k=%s Clusters' %(k))
    plt.legend(bbox_to_anchor=(1,1))
    plt.show()

# %% [markdown]
# ### 4.3. Average Linkage
#
# #### 4.3.1. Dendrogram
#
# Create a dendrogram using hierarchical agglomerative clustering with average linkage using your Hamming distance matrix.
# * Because this is a small dataset, we do not need/want to truncate our dendrogram results. You should be able to see the indices of each of your observations at the leaves of your dendrogram tree.
# * Make sure you are able to read the indices labels in your dendrogram.

# %%
dist_m = pdist(df_cat2, metric = 'hamming')
link = linkage(dist_m, method = 'average')

# %%
fig, ax = plt.subplots(figsize=(30, 30))
d = dendrogram(link, orientation='right', ax=ax)
ax.set_xlabel('Dissimilarity', fontsize=18)
ax.set_ylabel('Indices', fontsize=18)
plt.yticks(fontsize=10)
plt.title('Average Linkage', fontsize=18)
plt.show()

# %% [markdown]
# #### 4.3.2 t-SNE Individual Clustering Visualization
#
# Then for each of the clusterings with k=2,k=3,...,k=10 clusters, color code the points in your selected t-SNE plot with the respective cluster labels.

# %%
dist_s = squareform(pdist(df_cat2, metric = 'hamming'))
for k in range(2,11):
    #Clustering from dendrogram with k clusters
    hac = AgglomerativeClustering(n_clusters=k, affinity='precomputed', linkage='average')
    df_combo['predicted_cluster'] = hac.fit_predict(dist_s)
    
    #Map the resulting cluster labels onto our chosen t-SNE plot
    sns.scatterplot(x='x_projected',y='y_projected', hue='predicted_cluster', palette=sns.color_palette("husl", k), data=df_combo)
    plt.title('t-SNE Plot with Average Linkage Clustering with k=%s Clusters' %(k))
    plt.legend(bbox_to_anchor=(1,1))
    plt.show()

# %% [markdown]
# ### 4.4. Dendrogram Comparison
#
# Out of the three dendrograms that were created, which one do you think best helped us BOTH:
# * identifify any "main clusters" that exist in the dataset that are larger in size (as opposed to small singleton clusters) AND
# * identifty clusters in which we have evidence to suggest are meaningfully separated from each other in the dataset?
#
# Explain.

# %% [markdown]
# ### Note:
#
# Note that a more complete analysis may have also explored what attributes characterize some of the clusterings found in this "best" dendrogram that you selected in 4.4.
